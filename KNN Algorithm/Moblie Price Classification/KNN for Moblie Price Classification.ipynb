# %%
#Importing required libraries
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
#Importing the Dataset
df = pd.read_csv('mpc train.csv')

# %%
#Using "head()" method, we can know first 5 rows
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
#Using "tail()" method, we can know last 5 rows
df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
#Using "shape", we can know how many rows and colums are exsit in the dataset
df.shape
# Out:
# (2000, 21)

# %%
#To know the information that is in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#Gives summary of the dataset
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
#this will check if there are any missing values in the dataset
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#Checks if there are any duplicate datasets are there
df.duplicated().any()
# Out:
# np.False_

# %%
#Knows how many colums are there in the dataset
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
#Knows how many rows are there in the dataset 
df.loc()

# %%
# To know if there are any out of range datasets in red 
sns.jointplot(x='ram',y='price_range',data=df,color='red',kind='kde');

# %%
sns.jointplot(x='mobile_wt',y='price_range',data=df,kind='kde');

# %%
#Plotting it on the axis
sns.pointplot(y="int_memory", x="price_range", data=df)
# Out:
# <Axes: xlabel='price_range', ylabel='int_memory'>

# %%
#Shows if there are any outliers and box plot is very useful to use
sns.boxplot(x='price_range', y='battery_power', data=df)
plt.xlabel('Price Range')
plt.ylabel('Battery Power')
plt.title('Battery Power vs Price Range', weight='bold')
plt.show()

# %%
# This is how we use this to show the dataset
import plotly.express as px
fig = px.scatter(df.head(1000), x='ram', y='battery_power', color='price_range')
fig.show()

# %%
#
four_g = df['four_g'].value_counts()
plt.title('Percentage of Mobiles 4G or No 4G', weight='bold')
four_g.plot.pie(autopct="%.1f%%", labels=['4G', 'No 4G'],colors = ['#66b3ff','#99ff99'])
plt.show()

# %%
X = df.drop('price_range', axis=1)
y = df['price_range']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=100)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.score(X_test,y_test)
# Out:
# C:\Users\mohit\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning:
#
# Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#
#   File "C:\Users\mohit\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\mohit\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\mohit\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...
